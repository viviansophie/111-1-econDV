# %% [markdown]
# <a href="https://colab.research.google.com/github/viviansophie/111-1-econDV/blob/main/final_improveother.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load package and data
library(ggplot2)
# library(ggalt)

# %%
proglangs <- readxl::read_excel("/content/ProgrammingLanguage.xlsx")
head(proglangs)
p <- ggplot(data = proglangs, aes(x = reorder(Language, -value), y = value)) +
    geom_bar(fill = '#5B622E',stat = "identity")+
    labs(title="Statistic of the programming langauge" ,subtitle = "Unit: %",
       caption="Source: TIOBE index", y = "Percentage", x = "Programming Language")+
    theme(plot.title = element_text(size=22))
p
# Out:
#   Language     value
# 1 Python       16.66
# 2 C            16.56
# 3 C++          11.94
# 4 Java         11.82
# 5 C#            4.92
# 6 Visual Basic  3.94
# plot without title
