# %% [markdown]
# <a href="https://colab.research.google.com/github/viviansophie/111-1-econDV/blob/main/hw_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load package and data
library(ggplot2)
# library(ggalt)

# %%
mos <- read.csv("multi.csv")
# head(mos)
colnames(mos) <- c("no.", "hight","age","weight")
head(mos)
# mos_select <- mos[mos$]
# head(mos_select)
theme_set(theme_bw())

# Draw plot
g <- ggplot(data = mos, mapping = aes(x = hight	, y = weight)) 
g + geom_point() + 
  labs(title="Correlation of weight and hight", 
       subtitle="children from age 10-15", ) + 
  geom_smooth(method="loess", se=F)+
  # geom_encircle(aes(x=hight	, y=weigh), 
  #               data=mos, 
  #               color="red", 
  #               size=2, 
  #               expand=0.08) + 
  theme(axis.text.x = element_text(angle=65, vjust=0.6))
# Out:
#   no. hight age weight
# 1 1    85.0 11  50.0
# 2 2   150.0 16  72.0
# 3 3    90.0 14  64.3
# 4 4   112.5 14  69.0
# 5 5   102.5 14  62.4
# 6 6    84.5 12  59.3
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
