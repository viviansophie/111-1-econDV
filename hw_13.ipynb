# %% [markdown]
# <a href="https://colab.research.google.com/github/viviansophie/111-1-econDV/blob/main/hw_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load package and data
library(ggplot2)
# library(ggalt)

# %%
mos <- read.csv(" test.csv")
head(mos)
# Out:
#   Package    Model size k   eta epoch batch_count optimizer Optimizer_lr lr
# 1 ampligraph HolE  6000 300 50  1000  32           adam     1e-03        1e-03
# 2 ampligraph HolE  6000 300 50  3000  32           adam     1e-03        1e-03
# 3 ampligraph HolE  6000 300 50  4000  32           adam     1e-03        1e-03
# 4 ampligraph HolE  6000 300 50  2000  32           adam     1e-03        1e-03
# 5 ampligraph HolE  6000 300 50  4000  32           adam     6e-04        6e-04
# 6 ampligraph HolE  6000 300 50  1000  32           adam     6e-04        6e-04
#   mrr       Hit.10 Hit.5  Hit.3  Hit.1
# 1 0.3459932 0.51   42.33% 36.75% 26.58%
# 2 0.3478163 0.50   43.08% 37.79% 26.50%
# 3 0.3505920 0.50   43.67% 38.04% 26.92%
# 4 0.3510563 0.50   43.33% 38.13% 26.96%
# 5 0.3284316 0.49   41.42% 36.70% 24.14%
# 6 0.3238161 0.49   40.44% 35.80% 23.77%

# %%
p <- ggplot(mos, aes(x= Hit.10, y =mrr))
p + geom_point()+ 
    geom_smooth(method="loess")+
    labs(title="Correlation of Hit@10 and MRR" )
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
