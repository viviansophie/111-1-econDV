# %% [markdown]
# <a href="https://colab.research.google.com/github/viviansophie/111-1-econDV/blob/main/final_improveself.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load package and data
library(ggplot2)
# library(ggalt)

# %%
test <-readxl::read_excel("/content/ test.xlsx")
head(test)
# Out:
#   Package    Model size k   eta epoch batch_count optimizer Optimizer_lr lr
# 1 ampligraph HolE  6000 300 50  1000  32          adam      1e-03        1e-03
# 2 ampligraph HolE  6000 300 50  3000  32          adam      1e-03        1e-03
# 3 ampligraph HolE  6000 300 50  4000  32          adam      1e-03        1e-03
# 4 ampligraph HolE  6000 300 50  2000  32          adam      1e-03        1e-03
# 5 ampligraph HolE  6000 300 50  4000  32          adam      6e-04        6e-04
# 6 ampligraph HolE  6000 300 50  1000  32          adam      6e-04        6e-04
#   mrr       Hit10     Hit5      Hit3      Hit1
# 1 0.3459932 0.5129167 0.4233333 0.3675000 0.2658333
# 2 0.3478163 0.5029167 0.4308333 0.3779167 0.2650000
# 3 0.3505920 0.5029167 0.4366667 0.3804167 0.2691667
# 4 0.3510563 0.5012500 0.4333333 0.3812500 0.2695833
# 5 0.3284316 0.4930213 0.4142036 0.3669951 0.2413793
# 6 0.3238161 0.4880952 0.4043514 0.3579639 0.2376847

# %%
p1 <- ggplot(test,aes(x=epoch, y=Hit10, group=optimizer)) +
    geom_point(aes(shape = optimizer,color = lr),size=5)+
    labs(title=" Hit10 result under hyperparameter adjustment " ,
       caption="Source: This study")+
    theme(plot.title = element_text(size=20))
p1
# Out:
# plot without title

# %%
p3 <- ggplot(test,aes(x=Hit10, y=mrr, group=batch_count)) +
    # geom_line(aes(linetype=as.character(batch_count)))+
    geom_point(aes(shape = optimizer,color = lr),size=5)+
    stat_smooth(method = "loess")+
    # stat_quantile(quantiles = c(0.25,0.75))+
    labs(title="Correlation of Mrr and Hit@10 ratio" ,
       caption="Source: This study")+
    theme(plot.title = element_text(size=20))
p3
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “span too small.   fewer data values than degrees of freedom.”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 0.47864”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.0024774”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 2.7437e-06”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “span too small.   fewer data values than degrees of freedom.”
# ...
